# %% [markdown]
# # 네이버 뉴스 수집(from NAVER OpenAPI)
# - [API 목록](https://developers.naver.com/products/intro/plan/)

# %% [markdown]
# ## 검색 API 신청
# - [검색](https://developers.naver.com/products/search/)
# # - [오픈API이용신청](https://developers.naver.com/apps/#/register?defaultScope=search) (naver login 필요)

# %% [markdown]
# ### 애플리케이션 등록
# - 애플리케이션 이름
#   - sunmoon-search-학번
# - 사용 API
#   - 검색
# - 비로그인 오픈 API 서비스 환경(필수값)
#   - WEB 설정(임의의 주소)
#     - http://search-학번.sunmoon.ac.kr

# %% [markdown]
# ### api 사용 가이드
# - [비로그인 방식 오픈 API](https://developers.naver.com/docs/common/openapiguide/apilist.md#%EB%B9%84%EB%A1%9C%EA%B7%B8%EC%9D%B8-%EB%B0%A9%EC%8B%9D-%EC%98%A4%ED%94%88-api)
# - [검색 API](https://developers.naver.com/docs/common/openapiguide/apilist.md#%EA%B2%80%EC%83%89)
# - [뉴스 검색 API SPEC](https://developers.naver.com/docs/search/news/)
# - [검색 API 예제](https://developers.naver.com/docs/search/blog/)

# %% [markdown]
# ## 뉴스검색 with Python
# - 준비물
#   - [내 애플리케이션](https://developers.naver.com/apps/#/list) 의
#     - client_id
#     - client_secret
#
# ```
# # 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# # 네이버 검색 Open API 예제 - 블로그 검색
# import os
# import sys
# import urllib.request
# client_id = "YOUR_CLIENT_ID"
# client_secret = "YOUR_CLIENT_SECRET"
# encText = urllib.parse.quote("검색할 단어")
# url = "https://openapi.naver.com/v1/search/news.json?query=" + encText # json 결과
# # url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
# request = urllib.request.Request(url)
# request.add_header("X-Naver-Client-Id",client_id)
# request.add_header("X-Naver-Client-Secret",client_secret)
# response = urllib.request.urlopen(request)
# rescode = response.getcode()
# if(rescode==200):
#     response_body = response.read()
#     print(response_body.decode('utf-8'))
# else:
#     print("Error Code:" + rescode)
# ```

# %%
client_id = "mXN15H3J3i0n5oVnxE65"
client_secret = "aCPy_AlXQU"

# %% [markdown]
# ### 뉴스검색 실행
# - 키워드 : 아이폰

# %%
import os
import sys
import urllib.request
encText = urllib.parse.quote("아이폰")
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText  # json 결과
# url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
  response_body = response.read()
  print(response_body.decode('utf-8'))
else:
  print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Wed, 13 Jan 2021 16:14:12 +0900",
# "total": 578354,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "삼성, 갤럭시 S21 출고가 '확' 낮췄다…&quot;<b>아이폰</b> 12 견제&quot;",
# "originallink": "http://www.newsprime.co.kr/news/article.html?no=530533",
# "link": "http://www.newsprime.co.kr/news/article.html?no=530533",
# "description": "이는 애플의 첫 5G 단말 '<b>아이폰</b> 12' 시리즈의 높은 인기로 점유율을 경쟁에서 밀렸기 때문으로 추정된다. 따라서 삼성전자는 이번 100만원 이하로 출고가를 책정한 것은 <b>아이폰</b>12의 인기몰이를 견제하려는... ",
# "pubDate": "Wed, 13 Jan 2021 16:08:00 +0900"
#
# },
# {
# "title": "[마켓트렌드] 전 국민 코로나19 백신 접종 '성큼'… 수혜주는?",
# "originallink": "https://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2021011315340268823",
# "link": "https://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2021011315340268823",
# "description": "- <b>아이폰</b>12 전모델 OLED 채택 '흥행 성공' - 삼성전자 A5 투자 기대 - LG디스플레이, 벤츠 계기판 디스플레이 공급 - 스마트폰에서 자동차까지 수요 다변화 - AP시스템· 이녹스첨단소재 관심 * AP시스템 - 중소형 OLED 설비... ",
# "pubDate": "Wed, 13 Jan 2021 16:05:00 +0900"
#
# },
# {
# "title": "12월 대만 IT매출 57조원 사상최대 기록...“재택수요 증대로 호황&quot;",
# "originallink": "http://www.newsis.com/view/?id=NISX20210113_0001304254&cID=10101&pID=10100",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=003&aid=0010292545",
# "description": "<b>아이폰</b>과 서버에 강한 전자기기 위탁제조 훙하이 정밀도 32%나 크게 늘었다. 세계 최대 반도체 위탁생산 TSMC(대만적체전로제조)를 비롯한 유력 IT기업의 2020년 매출도 대폭 신장했다. 대만기업의 공급 대상은 애플과... ",
# "pubDate": "Wed, 13 Jan 2021 16:03:00 +0900"
#
# },
# {
# "title": "이번 연말정산은 민간 인증 서비스로…이통3사·카카오 등 각축",
# "originallink": "http://yna.kr/AKR20210113134100017?did=1195m",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0012138387",
# "description": "14일까지 패스 인증서를 발급한 고객을 대상으로 추첨으로 <b>아이폰</b>12·에어팟 프로·스타벅스 모바일 상품권 등을 주는 행사도 마련한다. 페이코 인증서는 앱 내 '더보기' 탭 우상단에 위치한 인증서를 선택한 다음 본인... ",
# "pubDate": "Wed, 13 Jan 2021 16:01:00 +0900"
#
# },
# {
# "title": "[뉴스핌 뉴스레터 Today ANDA] 1월 13일",
# "originallink": "http://www.newspim.com/news/view/20210113000903",
# "link": "http://www.newspim.com/news/view/20210113000903",
# "description": "거점화·대형화가 폐쇄 가속도 ▲ 삼성·대치 등 강남권 토지거래허가구역서도 주복·오파스텔 건설 한층 쉬어진다 ▲그린·디지털뉴딜 5년간 30조 금융지원…해외수주 두배로 확대 ▲&quot;애플카, <b>아이폰</b> 같은 혁신자될... ",
# "pubDate": "Wed, 13 Jan 2021 16:01:00 +0900"
#
# },
# {
# "title": "'<b>아이폰</b> 잡아라'… 삼성 갤럭시S21, 충전기·이어폰 빼고 99만9900원 확정",
# "originallink": "http://www.getnews.co.kr/news/articleView.html?idxno=509541",
# "link": "http://www.getnews.co.kr/news/articleView.html?idxno=509541",
# "description": "애플의 <b>아이폰</b>12 시리즈가 최저 95만원으로 책정된 점도 무시 못한 것으로 보인다. 시장조사기관 스트래티지 애널리틱스에 따르면 애플은 <b>아이폰</b> 출시 두 달 만에 지난해 5G 스마트폰 점유율 19.2%를 기록하며... ",
# "pubDate": "Wed, 13 Jan 2021 16:01:00 +0900"
#
# },
# {
# "title": "‘가격·패키지 슬림해진다’...삼성전자, 갤럭시S21 출고가 99만 9900원",
# "originallink": "http://inthenews.co.kr/article-88052/",
# "link": "http://inthenews.co.kr/article-88052/",
# "description": "앞서 애플은 지난해 <b>아이폰</b>12를 출시하면서 ‘환경 보호’를 이유로 더이상 이어폰과 충전기를 제공하지 않겠다고 선언한 바 있습니다. 갤럭시버즈 프로도 공개됩니다. 갤럭시버즈 프로는 11㎜ 우퍼와 6.5... ",
# "pubDate": "Wed, 13 Jan 2021 16:00:00 +0900"
#
# },
# {
# "title": "이통3사 &quot;연말정산 간소화 서비스 PASS 인증서로 쉽고 간편하게&quot;",
# "originallink": "http://www.babytimes.co.kr/news/articleView.html?idxno=42669",
# "link": "http://www.babytimes.co.kr/news/articleView.html?idxno=42669",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 오는 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b>... ",
# "pubDate": "Wed, 13 Jan 2021 16:00:00 +0900"
#
# },
# {
# "title": "삼성전자 ‘승부수’ 갤럭시S21 전작보다 가격 낮췄다",
# "originallink": "https://www.ekn.kr/web/view.php?key=20210113010002700",
# "link": "https://www.ekn.kr/web/view.php?key=20210113010002700",
# "description": "삼성전자는 전작 갤럭시S20의 부진을 만회하고, 애플 <b>아이폰</b>12의 인기를 견제하기 위해 ‘가격 인하’ 카드를 꺼낸 것으로 풀이된다.대신 일부 사양이 하향 조정된다. 기본 구성품에서 충전기와 유선... ",
# "pubDate": "Wed, 13 Jan 2021 15:57:00 +0900"
#
# },
# {
# "title": "디자인 씽킹 하라! '선택과 집중보다 균형이 중요한 이유'",
# "originallink": "http://www.lecturernews.com/news/articleView.html?idxno=59361",
# "link": "http://www.lecturernews.com/news/articleView.html?idxno=59361",
# "description": "이후 <b>아이폰</b>, 아이패드로 연타석 홈런을 몰아치며 시장을 주도하는 아이콘제품을 만들어 낼 수 있었던 것이다. 디자인 씽킹의 저자 로저마틴은 이렇게 말하고 있다. &quot;앞으로의 시대는 분석과 직관이 균형을 이루는... ",
# "pubDate": "Wed, 13 Jan 2021 15:56:00 +0900"
#
# }
# ]
# }

# %% [markdown]
# ### 뉴스검색 옵션 변경

# %%
import os
import sys
import urllib.request
encText = urllib.parse.quote("아이폰")
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText  + "&display=100" # json 결과
# url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
  response_body = response.read()
  print(response_body.decode('utf-8'))
else:
  print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Wed, 13 Jan 2021 16:14:18 +0900",
# "total": 578354,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "삼성, 갤럭시 S21 출고가 '확' 낮췄다…&quot;<b>아이폰</b> 12 견제&quot;",
# "originallink": "http://www.newsprime.co.kr/news/article.html?no=530533",
# "link": "http://www.newsprime.co.kr/news/article.html?no=530533",
# "description": "이는 애플의 첫 5G 단말 '<b>아이폰</b> 12' 시리즈의 높은 인기로 점유율을 경쟁에서 밀렸기 때문으로 추정된다. 따라서 삼성전자는 이번 100만원 이하로 출고가를 책정한 것은 <b>아이폰</b>12의 인기몰이를 견제하려는... ",
# "pubDate": "Wed, 13 Jan 2021 16:08:00 +0900"
#
# },
# {
# "title": "[마켓트렌드] 전 국민 코로나19 백신 접종 '성큼'… 수혜주는?",
# "originallink": "https://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2021011315340268823",
# "link": "https://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2021011315340268823",
# "description": "- <b>아이폰</b>12 전모델 OLED 채택 '흥행 성공' - 삼성전자 A5 투자 기대 - LG디스플레이, 벤츠 계기판 디스플레이 공급 - 스마트폰에서 자동차까지 수요 다변화 - AP시스템· 이녹스첨단소재 관심 * AP시스템 - 중소형 OLED 설비... ",
# "pubDate": "Wed, 13 Jan 2021 16:05:00 +0900"
#
# },
# {
# "title": "12월 대만 IT매출 57조원 사상최대 기록...“재택수요 증대로 호황&quot;",
# "originallink": "http://www.newsis.com/view/?id=NISX20210113_0001304254&cID=10101&pID=10100",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=003&aid=0010292545",
# "description": "<b>아이폰</b>과 서버에 강한 전자기기 위탁제조 훙하이 정밀도 32%나 크게 늘었다. 세계 최대 반도체 위탁생산 TSMC(대만적체전로제조)를 비롯한 유력 IT기업의 2020년 매출도 대폭 신장했다. 대만기업의 공급 대상은 애플과... ",
# "pubDate": "Wed, 13 Jan 2021 16:03:00 +0900"
#
# },
# {
# "title": "'<b>아이폰</b> 잡아라'… 삼성 갤럭시S21, 충전기·이어폰 빼고 99만9900원 확정",
# "originallink": "http://www.getnews.co.kr/news/articleView.html?idxno=509541",
# "link": "http://www.getnews.co.kr/news/articleView.html?idxno=509541",
# "description": "애플의 <b>아이폰</b>12 시리즈가 최저 95만원으로 책정된 점도 무시 못한 것으로 보인다. 시장조사기관 스트래티지 애널리틱스에 따르면 애플은 <b>아이폰</b> 출시 두 달 만에 지난해 5G 스마트폰 점유율 19.2%를 기록하며... ",
# "pubDate": "Wed, 13 Jan 2021 16:01:00 +0900"
#
# },
# {
# "title": "이번 연말정산은 민간 인증 서비스로…이통3사·카카오 등 각축",
# "originallink": "http://yna.kr/AKR20210113134100017?did=1195m",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0012138387",
# "description": "14일까지 패스 인증서를 발급한 고객을 대상으로 추첨으로 <b>아이폰</b>12·에어팟 프로·스타벅스 모바일 상품권 등을 주는 행사도 마련한다. 페이코 인증서는 앱 내 '더보기' 탭 우상단에 위치한 인증서를 선택한 다음 본인... ",
# "pubDate": "Wed, 13 Jan 2021 16:01:00 +0900"
#
# },
# {
# "title": "[뉴스핌 뉴스레터 Today ANDA] 1월 13일",
# "originallink": "http://www.newspim.com/news/view/20210113000903",
# "link": "http://www.newspim.com/news/view/20210113000903",
# "description": "거점화·대형화가 폐쇄 가속도 ▲ 삼성·대치 등 강남권 토지거래허가구역서도 주복·오파스텔 건설 한층 쉬어진다 ▲그린·디지털뉴딜 5년간 30조 금융지원…해외수주 두배로 확대 ▲&quot;애플카, <b>아이폰</b> 같은 혁신자될... ",
# "pubDate": "Wed, 13 Jan 2021 16:01:00 +0900"
#
# },
# {
# "title": "‘가격·패키지 슬림해진다’...삼성전자, 갤럭시S21 출고가 99만 9900원",
# "originallink": "http://inthenews.co.kr/article-88052/",
# "link": "http://inthenews.co.kr/article-88052/",
# "description": "앞서 애플은 지난해 <b>아이폰</b>12를 출시하면서 ‘환경 보호’를 이유로 더이상 이어폰과 충전기를 제공하지 않겠다고 선언한 바 있습니다. 갤럭시버즈 프로도 공개됩니다. 갤럭시버즈 프로는 11㎜ 우퍼와 6.5... ",
# "pubDate": "Wed, 13 Jan 2021 16:00:00 +0900"
#
# },
# {
# "title": "이통3사 &quot;연말정산 간소화 서비스 PASS 인증서로 쉽고 간편하게&quot;",
# "originallink": "http://www.babytimes.co.kr/news/articleView.html?idxno=42669",
# "link": "http://www.babytimes.co.kr/news/articleView.html?idxno=42669",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 오는 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b>... ",
# "pubDate": "Wed, 13 Jan 2021 16:00:00 +0900"
#
# },
# {
# "title": "삼성전자 ‘승부수’ 갤럭시S21 전작보다 가격 낮췄다",
# "originallink": "https://www.ekn.kr/web/view.php?key=20210113010002700",
# "link": "https://www.ekn.kr/web/view.php?key=20210113010002700",
# "description": "삼성전자는 전작 갤럭시S20의 부진을 만회하고, 애플 <b>아이폰</b>12의 인기를 견제하기 위해 ‘가격 인하’ 카드를 꺼낸 것으로 풀이된다.대신 일부 사양이 하향 조정된다. 기본 구성품에서 충전기와 유선... ",
# "pubDate": "Wed, 13 Jan 2021 15:57:00 +0900"
#
# },
# {
# "title": "디자인 씽킹 하라! '선택과 집중보다 균형이 중요한 이유'",
# "originallink": "http://www.lecturernews.com/news/articleView.html?idxno=59361",
# "link": "http://www.lecturernews.com/news/articleView.html?idxno=59361",
# "description": "이후 <b>아이폰</b>, 아이패드로 연타석 홈런을 몰아치며 시장을 주도하는 아이콘제품을 만들어 낼 수 있었던 것이다. 디자인 씽킹의 저자 로저마틴은 이렇게 말하고 있다. &quot;앞으로의 시대는 분석과 직관이 균형을 이루는... ",
# "pubDate": "Wed, 13 Jan 2021 15:56:00 +0900"
#
# },
# {
# "title": "국민인증서 ‘패스’로 연말정산 더 쉽고 간편하게…15일부터 서비스 이용",
# "originallink": "http://www.sportsseoul.com/news/read/1002008?ref=naver",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=468&aid=0000732974",
# "description": "통해 <b>아이폰</b>12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 2월 19일까지 ‘패스 인증서’로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b>12 프로... ",
# "pubDate": "Wed, 13 Jan 2021 15:42:00 +0900"
#
# },
# {
# "title": "삼성전자, 사양 낮춘 99만원대 '갤럭시S21'으로 '<b>아이폰</b>12' 잡을까",
# "originallink": "http://www.inews24.com/view/1334648",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=031&aid=0000578885",
# "description": "애플의 '<b>아이폰</b>12' 인기를 막을 수 있을 지 주목된다. 다만 가격이 저렴해진 대신 전작인 '갤럭시S20'에... 이처럼 삼성전자가 '갤럭시S21'의 출고가를 낮추는 것은 애플의 '<b>아이폰</b>12' 시리즈가 최저 95만 원으로... ",
# "pubDate": "Wed, 13 Jan 2021 15:39:00 +0900"
#
# },
# {
# "title": "애플, 에어팟 보관·충전 가능한 케이스 특허 획득(작성완료)",
# "originallink": "https://www.theguru.co.kr/news/article.html?no=17849",
# "link": "https://www.theguru.co.kr/news/article.html?no=17849",
# "description": "있는 <b>아이폰</b> 케이스 특허를 취득했다. 13일 업계에 따르면 애플은 12일(현지시간) 미국 특허청(USPTO)로부터... 가능한 <b>아이폰</b> 케이스가 출시될 수 있다고 보고 있다. 애플이 에어팟 보관 및 충전이 가능한 <b>아이폰</b> 케이스... ",
# "pubDate": "Wed, 13 Jan 2021 15:32:00 +0900"
#
# },
# {
# "title": "쿠팡, 로켓모바일에 중고폰 보상판매 서비스 추가",
# "originallink": "http://www.edaily.co.kr/news/newspath.asp?newsid=03630966628917392",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=018&aid=0004827908",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개다. 신규 폰 구매 후 구매완료 페이지에서 ‘쓰던 폰 보상판매’ 신청 버튼을 눌러 중고폰 보상판매... ",
# "pubDate": "Wed, 13 Jan 2021 15:27:00 +0900"
#
# },
# {
# "title": "갤럭시S21, 99만원으로 S20부진 털어낸다",
# "originallink": "http://www.fnnews.com/news/202101131443529861",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=014&aid=0004564461",
# "description": "또 전작 갤럭시S20의 부진을 만회하고 애플 <b>아이폰</b>12의 인기를 견제하기 위해 가격을 낮췄을 것이라는 분석이다. <b>아이폰</b>12 미니(64GB·94만6000원)보다 5만원가량 비싸지만 저장용량 측면에서는 갤럭시S21(128GB)이... ",
# "pubDate": "Wed, 13 Jan 2021 15:22:00 +0900"
#
# },
# {
# "title": "이통3사 &quot;PASS로 3초만에 연말정산 접속 끝&quot;",
# "originallink": "https://www.asiatime.co.kr/news/newsview.php?ncode=1065589719925122",
# "link": "https://www.asiatime.co.kr/news/newsview.php?ncode=1065589719925122",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 15:17:00 +0900"
#
# },
# {
# "title": "[오늘의 장바구니] 홈플러스·GS홈쇼핑·옥션·롯데호텔 외",
# "originallink": "http://www.newsprime.co.kr/news/article.html?no=530526",
# "link": "http://www.newsprime.co.kr/news/article.html?no=530526",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개로 다양하다. 신규 폰 구매 후 구매완료 페이지에서 '쓰던 폰 보상판매' 신청 버튼을 눌러 중고폰... ",
# "pubDate": "Wed, 13 Jan 2021 15:15:00 +0900"
#
# },
# {
# "title": "[줌인] 애플의 '수평분업 생산', 자동차산업에서도 통할까",
# "originallink": "https://biz.chosun.com/site/data/html_dir/2021/01/13/2021011302001.html?utm_source=naver&utm_medium=original&utm_campaign=biz",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=366&aid=0000651803",
# "description": "애플카, '수평적' 생산모델 도입 전망…&quot;<b>아이폰</b> 만들듯 차 만든다&quot; 잠재적 애플카 부품업체들, 벌써부터 세계... 전문가들 사이에서는 애플이 <b>아이폰</b>처럼 수지적 통합 모델을 선택할 것으로 전망하며 이는 세계 자동차 산업... ",
# "pubDate": "Wed, 13 Jan 2021 15:12:00 +0900"
#
# },
# {
# "title": "통신3사 &quot;직장인 연말정산 '패스'로 3초만에 간편인증&quot;",
# "originallink": "http://www.seouleconews.com/news/articleView.html?idxno=58664",
# "link": "http://www.seouleconews.com/news/articleView.html?idxno=58664",
# "description": "추첨으로 <b>아이폰</b>12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 15일부터 2월19일까지 패스 인증서로 국세청 홈택스 연말정산 간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12 프로 맥스, 아이패드... ",
# "pubDate": "Wed, 13 Jan 2021 15:12:00 +0900"
#
# },
# {
# "title": "갤럭시S21, 충전기 빼고 99만9900원에 나온다",
# "originallink": "https://biz.chosun.com/site/data/html_dir/2021/01/13/2021011301997.html?utm_source=naver&utm_medium=original&utm_campaign=biz",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=366&aid=0000651802",
# "description": "15일부터 예약판매, 애플 <b>아이폰</b>12 인기에 맞불 삼성전자의 차세대 플래그십 스마트폰 ‘갤럭시S21’의... 삼성전자가 가격대를 낮추는 승부수를 띄운 것은 전작 갤럭시S20의 부진을 만회하고 애플의 <b>아이폰</b>12... ",
# "pubDate": "Wed, 13 Jan 2021 15:11:00 +0900"
#
# },
# {
# "title": "이통3사 “연말정산, PASS로 간편하게 하세요”",
# "originallink": "http://www.segyebiz.com/newsView/20210113512758?OutUrl=naver",
# "link": "http://www.segyebiz.com/newsView/20210113512758?OutUrl=naver",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일 까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 15:09:00 +0900"
#
# },
# {
# "title": "갤럭시S21, 충전기·이어폰 빼고 99.99만원 출시…삼성의 노림수는",
# "originallink": "http://news.mt.co.kr/mtview.php?no=2021011314480816441",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=008&aid=0004528032",
# "description": "현재 흥행 돌풍을 잇고 있는 애플의 첫 5G 단말기인 '<b>아이폰</b>12' 시리즈를 견제하려는 포석도 있다. 지난해 4분기 출시된 <b>아이폰</b>12 시리즈는 출시 직후 큰 인기를 끌며 시장에서 높은 점유율을 차지하고 있다.... ",
# "pubDate": "Wed, 13 Jan 2021 15:08:00 +0900"
#
# },
# {
# "title": "3초만에 연말정산 접속 끝…PASS 인증서로 쉽고 간편하게",
# "originallink": "http://www.thedailypost.kr/news/articleView.html?idxno=78755",
# "link": "http://www.thedailypost.kr/news/articleView.html?idxno=78755",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일 까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 15:04:00 +0900"
#
# },
# {
# "title": "갤럭시S20 BTS에디션 재고정리 가격인하, S20울트라 높은 할인에 인기 역주행",
# "originallink": "http://www.sisamagazine.co.kr/news/articleView.html?idxno=341519",
# "link": "http://www.sisamagazine.co.kr/news/articleView.html?idxno=341519",
# "description": "또한 공시지원금 상향으로 크게 가격이 인하된 갤럭시노트20, <b>아이폰</b>12, 갤럭시S20, 갤럭시노트10 모델을 10~20만원대 할인가격으로 판매하고 있고 LG 벨벳, 갤럭시S20 FE, 갤럭시노트9, <b>아이폰</b>SE2, 갤럭시A30, 갤럭시A80... ",
# "pubDate": "Wed, 13 Jan 2021 15:01:00 +0900"
#
# },
# {
# "title": "이마트24, 보조배터리 공유 서비스 ‘충전돼지’ 도입",
# "originallink": "http://www.newsway.co.kr/news/view?tp=1&ud=2021011314564959499",
# "link": "http://www.newsway.co.kr/news/view?tp=1&ud=2021011314564959499",
# "description": "충전돼지 보조배터리에는 마이크로5핀, 라이트닝8핀(<b>아이폰</b>), C타입(갤럭시) 등 3개의 케이블이 있어 스마트폰을 비롯해 무선이어폰, 태블릿, 전자담배 등 다양한 전자기기의 충전을 동시에 할 수 있다. 최초 30분까지... ",
# "pubDate": "Wed, 13 Jan 2021 15:00:00 +0900"
#
# },
# {
# "title": "KT 등 통신 3사, &quot;연말정산 서비스 접속 'PASS'로 간편하게&quot; 적극 홍보 나선다",
# "originallink": "https://www.insight.co.kr/news/320665",
# "link": "https://www.insight.co.kr/news/320665",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다.연말정산 기간인 15일부터 내달 19일 까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12 프로... ",
# "pubDate": "Wed, 13 Jan 2021 15:00:00 +0900"
#
# },
# {
# "title": "삼성 '갤럭시S21' 99만원부터 출시 예정…BTS폰 또 나오나?",
# "originallink": "https://www.hankyung.com/economy/article/202101138340a",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004482968",
# "description": "해당카페에서는 신제품 출시로 인한 갤럭시S20시리즈, 노트20 재고 소진에 나섰고, <b>아이폰</b>12 시리즈는 최근 상향된 공시지원금을 반영해 소비자의 부담을 낮춰 기획전을 열고 있다. 갤럭시S21 사전예약과 재고소진... ",
# "pubDate": "Wed, 13 Jan 2021 15:00:00 +0900"
#
# },
# {
# "title": "&quot;최신폰 사고 쓰던폰 보상도 한번에&quot;...쿠팡, ‘로켓모바일’에 중고기기 매입...",
# "originallink": "https://www.etoday.co.kr/news/view/1983982",
# "link": "https://www.etoday.co.kr/news/view/1983982",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개로 다양하다. 신규 폰 구매 후 구매완료 페이지에서 ‘쓰던 폰 보상판매’ 신청 버튼을 눌러 중고폰... ",
# "pubDate": "Wed, 13 Jan 2021 14:59:00 +0900"
#
# },
# {
# "title": "이통사 &quot;패스 인증서, 인증서 발급까지 3초면 충분&quot;",
# "originallink": "http://www.digitaltoday.co.kr/news/articleView.html?idxno=260098",
# "link": "http://www.digitaltoday.co.kr/news/articleView.html?idxno=260098",
# "description": "통해 <b>아이폰</b>12, 에어팟 프로, 스타벅스 모바일 상품권을 증정하는 이벤트도 한다. 연말정산 기간인 오는 15일부터 다음달 19일까지 패스 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용하면 추첨을 통해 <b>아이폰</b>12... ",
# "pubDate": "Wed, 13 Jan 2021 14:58:00 +0900"
#
# },
# {
# "title": "'충전돼지면 걱정 끝' 이마트24, 보조배터리 공유 플랫폼으로",
# "originallink": "http://theviewers.co.kr/View.aspx?No=1415384",
# "link": "http://theviewers.co.kr/View.aspx?No=1415384",
# "description": "충전돼지 보조배터리에는 마이크로5핀, 라이트닝8핀(<b>아이폰</b>), C타입(갤럭시) 등 3개의 케이블이 있어 스마트폰을 비롯해 무선이어폰, 태블릿, 전자담배 등 다양한 전자기기의 충전을 동시에 할 수 있다. 최초 30분까지... ",
# "pubDate": "Wed, 13 Jan 2021 14:49:00 +0900"
#
# },
# {
# "title": "가열되는 전기차 경쟁…완성차업체 속도 내고 IT업체도 도전장",
# "originallink": "http://yna.kr/AKR20210113109800003?did=1195m",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0012138036",
# "description": "앞서 애플 <b>아이폰</b>의 위탁생산업체로 유명한 대만 폭스콘과 중국의 전기차 스타트업 바이튼, LG전자와 마그나, 폭스바겐 등이 '애플카 생산업체' 후보로 언급되기도 했다. 업계에서는 이번 협업이 성사된다면 전기차... ",
# "pubDate": "Wed, 13 Jan 2021 14:47:00 +0900"
#
# },
# {
# "title": "'애플글래스' 출시 당겨지나...주변기기 잠금해제 특허 등록도",
# "originallink": "http://www.ddaily.co.kr/news/article.html?no=207843",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=138&aid=0002097434",
# "description": "- 애플글래스 착용 후 <b>아이폰</b> 주변에만 가도 '잠금해제' 애플이 연구 중인 증강현실(AR) 기기 ‘애플글래스’... 12일(현지시각) 애플인사이더 등 외신에 따르면 애플은 애플글래스를 활용해 <b>아이폰</b>이나 아이패드 등 잠금해제... ",
# "pubDate": "Wed, 13 Jan 2021 14:46:00 +0900"
#
# },
# {
# "title": "이통 3사 &quot;'패스'로 3초 만에 연말정산 접속 끝&quot;",
# "originallink": "http://www.newscj.com/news/articleView.html?idxno=818694",
# "link": "http://www.newscj.com/news/articleView.html?idxno=818694",
# "description": "통해 <b>아이폰</b>12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산 간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b>12... ",
# "pubDate": "Wed, 13 Jan 2021 14:34:00 +0900"
#
# },
# {
# "title": "연말정산 간소화 서비스 PASS로 간단하게 인증 끝",
# "originallink": "http://www.kado.net/news/articleView.html?idxno=1056195",
# "link": "http://www.kado.net/news/articleView.html?idxno=1056195",
# "description": "통해 <b>아이폰</b> 12·에어팟 프로·스타벅스 모바일 상품권 등을 증정한다. 또한 연말정산 기간인 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 14:31:00 +0900"
#
# },
# {
# "title": "[글로벌-Biz24]노키아 5G스마트폰 ‘4종’ 출격대기…상반기 2종 출시",
# "originallink": "http://www.g-enews.com/ko-kr/news/article/news_all/2021011314213278601e71ea687c_1/article.html",
# "link": "http://www.g-enews.com/ko-kr/news/article/news_all/2021011314213278601e71ea687c_1/article.html",
# "description": "90년대 말부터 전 세계 피처폰 시장 강자였던 노키아는 <b>아이폰</b> 등 스마트폰이 대세에 적응하지 못해 경영위기에 놓였고 결국 2013년 단말기 사업을 마이크로소프트(MS)사에 매각했다. 이후 MS도 스마트폰 사업에... ",
# "pubDate": "Wed, 13 Jan 2021 14:30:00 +0900"
#
# },
# {
# "title": "통신3사, 국민인증서 'PASS'로 3초 만에 연말정산 접속 가능",
# "originallink": "http://www.thefirstmedia.net/news/articleView.html?idxno=69144",
# "link": "http://www.thefirstmedia.net/news/articleView.html?idxno=69144",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일 까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 14:30:00 +0900"
#
# },
# {
# "title": "&quot;PASS로 3초만에 연말정산 접속 끝&quot; ...통신3사, 'PASS 인증서' 공동 홍보",
# "originallink": "http://www.worktoday.co.kr/news/articleView.html?idxno=12872",
# "link": "http://www.worktoday.co.kr/news/articleView.html?idxno=12872",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 14:26:00 +0900"
#
# },
# {
# "title": "'LG유플러스' 공공서비스도 PASS 인증서로 쉽고 간편하게",
# "originallink": "http://www.newsfarm.co.kr/news/articleView.html?idxno=63107",
# "link": "http://www.newsfarm.co.kr/news/articleView.html?idxno=63107",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 14:20:00 +0900"
#
# },
# {
# "title": "'애플 글래스'로 <b>아이폰</b> 잠금 해제…특허 취득",
# "originallink": "https://www.theguru.co.kr/news/article.html?no=17844",
# "link": "https://www.theguru.co.kr/news/article.html?no=17844",
# "description": "<b>아이폰</b>, 맥북 등 개별 잠금 해제 대신 한 번에 내년 3월로 공개 미뤄져…출시는 2021년 말 이후  애플이 스마트안경 '애플글래스'로 <b>아이폰</b> 잠금을 자동 해제하는 기술 관련 특허를 내놓으며 연결성 기반 애플 생태계를... ",
# "pubDate": "Wed, 13 Jan 2021 14:20:00 +0900"
#
# },
# {
# "title": "국세청 연말정산 'PASS앱' 사용법은?",
# "originallink": "https://www.econovill.com/news/articleView.html?idxno=514559",
# "link": "https://www.econovill.com/news/articleView.html?idxno=514559",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일 까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 14:17:00 +0900"
#
# },
# {
# "title": "&quot;애플카, <b>아이폰</b>처럼 자동차산업 흔들 수도&quot;",
# "originallink": "http://news.einfomax.co.kr/news/articleView.html?idxno=4127094",
# "link": "http://news.einfomax.co.kr/news/articleView.html?idxno=4127094",
# "description": "JP모건은 애플이 <b>아이폰</b> 제조를 위탁하듯 자동차 생산도 완성차업체에 맡길 것이라며, 현대자동차를 유망한... 애플과 <b>아이폰</b> 생산을 맡은 대만 폭스콘은 모두 17%가 넘는 영업이익률을 올리고 있다. 애플이 자동차를... ",
# "pubDate": "Wed, 13 Jan 2021 14:17:00 +0900"
#
# },
# {
# "title": "통신3사 “PASS 인증서로 연말정산 쉽고 간편하게 한다”",
# "originallink": "http://www.nextdaily.co.kr/news/article.html?id=20210113800010",
# "link": "http://www.nextdaily.co.kr/news/article.html?id=20210113800010",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 14:17:00 +0900"
#
# },
# {
# "title": "이마트24, 보조배터리 공유 서비스 시작",
# "originallink": "http://www.dizzotv.com/site/data/html_dir/2021/01/13/2021011380154.html",
# "link": "http://www.dizzotv.com/site/data/html_dir/2021/01/13/2021011380154.html",
# "description": "충전돼지 보조배터리에는 마이크로5핀, 라이트닝8핀(<b>아이폰</b>), C타입(갤럭시) 등 3개의 케이블이 있어 스마트폰을 비롯해 무선이어폰, 태블릿, 전자담배 등 다양한 전자기기의 충전을 동시에 할 수 있다. 최초 30분까지... ",
# "pubDate": "Wed, 13 Jan 2021 14:16:00 +0900"
#
# },
# {
# "title": "삼성전자 갤럭시S21 출고가 99만9900원…<b>아이폰</b>12 견제구",
# "originallink": "https://www.asiatoday.co.kr/view.php?key=20210113010007362",
# "link": "https://www.asiatoday.co.kr/view.php?key=20210113010007362",
# "description": "첫 100만원↓ 5G 플래그십 <b>아이폰</b>12에 밀린 자존심 회복할까 삼성전자의 플래그십 스마트폰... 지난해 5G 스마트폰 시장에서 애플의 ‘<b>아이폰</b>12’에 밀리자 가격을 내리는 승부수를 던진 것으로 풀이된다.13일... ",
# "pubDate": "Wed, 13 Jan 2021 14:16:00 +0900"
#
# },
# {
# "title": "애플 '<b>아이폰</b>12' 4분기 중국에서 1800만대 판매.. 점유율 20% 돌파",
# "originallink": "http://kbench.com/?q=node/217544",
# "link": "http://kbench.com/?q=node/217544",
# "description": "애플 최신 <b>아이폰</b>12 라인업이 지난 4분기 중국에서 1800만대가 판매되면서 20% 점유율을 돌파했다고 외신이 대만 디지타임스를 인용해 12일(현지시간) 보도했다. 1차 출시국인 중국에서는 <b>아이폰</b>12 출시 초기 배송... ",
# "pubDate": "Wed, 13 Jan 2021 14:13:00 +0900"
#
# },
# {
# "title": "&quot;상생지원금 1000억 더 내야&quot;…공정위vs애플, 새 국면 예고",
# "originallink": "http://www.etnews.com/20210113000142",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=030&aid=0002923196",
# "description": "애플은 지난 2009년 <b>아이폰</b>3GS를 한국에 출시한 뒤 이통사에 TV와 옥외광고비 및 매장 내 전시·진열비 등을... 애플은 잠정 동의의결안에서 <b>아이폰</b> 사용자 수리비 10% 할인 등 1000억원 규모의 상생 지원 추진, 이통사와... ",
# "pubDate": "Wed, 13 Jan 2021 14:06:00 +0900"
#
# },
# {
# "title": "'스마트폰 애프터마켓' 큰 장 섰다",
# "originallink": "https://www.hankyung.com/economy/article/202101136486i",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004482936",
# "description": "'<b>아이폰</b> 9월, 갤럭시S 2월'은 스마트폰 업계에서 지난 5년간 하나의 공식이었다. <b>아이폰</b>이 언팩에 나선 후 5개월이 지나 갤럭시S 신제품이 공개되는 식이었다. 이 공식이 올해 처음으로 깨질 것이라는 관측이다. <b>아이폰</b>12가... ",
# "pubDate": "Wed, 13 Jan 2021 14:05:00 +0900"
#
# },
# {
# "title": "이마트24, 보조배터리 공유 플랫폼 된다...‘충전돼지’ 도입",
# "originallink": "https://www.etoday.co.kr/news/view/1983979",
# "link": "https://www.etoday.co.kr/news/view/1983979",
# "description": "충전돼지 보조배터리에는 마이크로5핀, 라이트닝8핀(<b>아이폰</b>), C타입(갤럭시) 등 3개의 케이블이 있어 스마트폰을 비롯해 무선이어폰, 태블릿, 전자담배 등 다양한 전자기기의 충전을 동시에 할 수 있다. 최초 30분까지... ",
# "pubDate": "Wed, 13 Jan 2021 14:02:00 +0900"
#
# },
# {
# "title": "15일부터 PASS 인증서로 연말정산 서비스 접속 가능",
# "originallink": "http://www.ilovepc.co.kr/news/articleView.html?idxno=37629",
# "link": "http://www.ilovepc.co.kr/news/articleView.html?idxno=37629",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 14:01:00 +0900"
#
# },
# {
# "title": "중고폰 전문 '노란마켓' 중고<b>아이폰</b> 구입과 수리 서비스 주의사항 전해",
# "originallink": "http://www.job-post.co.kr/news/articleView.html?idxno=14448",
# "link": "http://www.job-post.co.kr/news/articleView.html?idxno=14448",
# "description": "중고<b>아이폰</b>, 갤럭시 등의 중고공기계를 구입하는 이들이 늘어나는 추세다. 이러한 가운데 중고폰매입, 판매를 전문으로 하는 업체 노란마켓는 중고폰판매, 매입 및 <b>아이폰</b>수리 서비스를 이용하는 이들도 증가했다고... ",
# "pubDate": "Wed, 13 Jan 2021 14:00:00 +0900"
#
# },
# {
# "title": "'맘스폰' <b>아이폰</b>12 미니, <b>아이폰</b>12 가격인하 더불어 <b>아이폰</b>SE2·<b>아이폰</b>7 최대...",
# "originallink": "http://www.cctoday.co.kr/news/articleView.html?idxno=2118108",
# "link": "http://www.cctoday.co.kr/news/articleView.html?idxno=2118108",
# "description": "삼성전자의 신제품 갤럭시S21 시리즈에 대한 대중의 기대가 높은 한편 지난해 출시된 애플의 <b>아이폰</b>12 시리즈 중 <b>아이폰</b>12 미니, <b>아이폰</b>12 모델의 공시지원금이 대폭 상향돼 대중의 눈길을 끌고 있다. <b>아이폰</b>12... ",
# "pubDate": "Wed, 13 Jan 2021 14:00:00 +0900"
#
# },
# {
# "title": "&quot;LG유플러스&quot; 공공서비스도 PASS 인증서로 쉽고 간편하게",
# "originallink": "https://www.lkp.news/news/article.html?no=11783",
# "link": "https://www.lkp.news/news/article.html?no=11783",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다.또 연말정산 기간인 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12 프로... ",
# "pubDate": "Wed, 13 Jan 2021 13:57:00 +0900"
#
# },
# {
# "title": "통신3사, PASS 앱 통한 연말정산 고객 대상 경품 이벤트",
# "originallink": "http://www.joseilbo.com/news/news_read.php?uid=414655&class=78&grp=",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=123&aid=0002238111",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정하고 15일부터 다음 달 19일 까지 국세청 홈택스 연말정산간소화 이용자를 대상으로 추첨을 통해 <b>아이폰</b> 12 프로 맥스, 아이패드 에어4, 백화점 상품권... ",
# "pubDate": "Wed, 13 Jan 2021 13:54:00 +0900"
#
# },
# {
# "title": "갤럭시S21 출고가 90만원대, 삼성전자의 복심은?",
# "originallink": "http://www.fnnews.com/news/202101131334279817",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=014&aid=0004564347",
# "description": "또 전작 갤럭시S20의 부진을 만회하고 애플 <b>아이폰</b>12의 인기를 견제하기 위해 가격을 낮췄을 것이라는 분석이다. 갤럭시S20 시리즈는 비싼 가격 책정과 코로나19로 인한 스마트폰 시장 침체가 겹치면서 전작... ",
# "pubDate": "Wed, 13 Jan 2021 13:51:00 +0900"
#
# },
# {
# "title": "쿠팡, 로켓모바일에 중고폰 보상판매 서비스 추가",
# "originallink": "http://www.enewstoday.co.kr/news/articleView.html?idxno=1443762",
# "link": "http://www.enewstoday.co.kr/news/articleView.html?idxno=1443762",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개로 다양하다. 신규 폰 구매 후 구매완료 페이지에서 '쓰던 폰 보상판매' 신청 버튼을 눌러 중고폰... ",
# "pubDate": "Wed, 13 Jan 2021 13:50:00 +0900"
#
# },
# {
# "title": "통신3사 &quot;국민인증서 PASS로 3초만에 연말정산 접속 끝&quot;",
# "originallink": "https://www.asiatoday.co.kr/view.php?key=20210113010007341",
# "link": "https://www.asiatoday.co.kr/view.php?key=20210113010007341",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다.또 연말정산 기간인 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12 프로... ",
# "pubDate": "Wed, 13 Jan 2021 13:49:00 +0900"
#
# },
# {
# "title": "갤럭시S21 추가정보 유출, 충전기랑 이어폰 빠지고 색상 더 추가돼",
# "originallink": "http://www.betanews.net:8080/article/1249852.html",
# "link": "http://www.betanews.net:8080/article/1249852.html",
# "description": "애플은 지난해 <b>아이폰</b>12를 출시할때 환경보호를 이유로 처음으로 스마트폰 기본구성에서 이어폰과 충전기를 빼기 시작했다. 당시 삼성은 애플의 이러한 결정을 비난하며 자신들은 충전기와 이어폰을 제공하고 있다는... ",
# "pubDate": "Wed, 13 Jan 2021 13:48:00 +0900"
#
# },
# {
# "title": "PASS, 15일부터 연말정산 서비스 접속 가능",
# "originallink": "http://www.ftoday.co.kr/news/articleView.html?idxno=210338",
# "link": "http://www.ftoday.co.kr/news/articleView.html?idxno=210338",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 13:47:00 +0900"
#
# },
# {
# "title": "'99.99' 갤럭시 S21 가격도 '혁신적'",
# "originallink": "https://www.techm.kr/news/articleView.html?idxno=79351",
# "link": "https://www.techm.kr/news/articleView.html?idxno=79351",
# "description": "앞서 애플이 지난해 '<b>아이폰</b>12'를 출시하며 환경 보호를 이유로 이어폰과 충전기를 패키지에서 제외시킨 행보를 따라가는 셈이다. 당시 애플은 기본 충전기를 패키지에서 빼고 '맥세이프'라는 새로운 충전... ",
# "pubDate": "Wed, 13 Jan 2021 13:46:00 +0900"
#
# },
# {
# "title": "“몰빵→10색→충전기·이어폰無→가격” 갤럭시S21 완전정복! [IT선빵!]",
# "originallink": "http://news.heraldcorp.com/view.php?ud=20210113000682",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=016&aid=0001778585",
# "description": "지난해 10월 첫번째 5G폰 ‘<b>아이폰</b>12’를 출시한 애플이 돌풍을 일으키고 있기 때문이다. 시장조사업체 스트래티지 애널리틱스(SA) 따르면 애플은 지난해 5230만대의 5G 스마트폰을 출하하며, 순식간에 삼성전자... ",
# "pubDate": "Wed, 13 Jan 2021 13:42:00 +0900"
#
# },
# {
# "title": "쿠팡, 로켓모바일에 중고폰 보상판매 서비스 추가…간편 시세 조회와 최고 수...",
# "originallink": "http://sports.chosun.com/news/ntype.htm?id=202101140100086100005334&servicedate=20210113",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=076&aid=0003681391",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개로 다양하다. 신규 폰 구매 후 구매완료 페이지에서 '쓰던 폰 보상판매' 신청 버튼을 눌러 중고폰... ",
# "pubDate": "Wed, 13 Jan 2021 13:41:00 +0900"
#
# },
# {
# "title": "이마트24, 보조배터리 공유 플랫폼 된다...백퍼센트와 손잡고 '충전돼지' 도입",
# "originallink": "http://www.updownnews.co.kr/news/articleView.html?idxno=227264",
# "link": "http://www.updownnews.co.kr/news/articleView.html?idxno=227264",
# "description": "충전돼지 보조배터리에는 마이크로5핀, 라이트닝8핀(<b>아이폰</b>), C타입(갤럭시) 등 3개의 케이블이 있어 스마트폰을 비롯해 무선이어폰, 태블릿, 전자담배 등 다양한 전자기기의 충전을 동시에 할 수 있다. 최초 30분까지... ",
# "pubDate": "Wed, 13 Jan 2021 13:31:00 +0900"
#
# },
# {
# "title": "PASS 국민인증서 만들기 대작전 펼쳐",
# "originallink": "http://it.chosun.com/site/data/html_dir/2021/01/13/2021011301603.html",
# "link": "http://it.chosun.com/site/data/html_dir/2021/01/13/2021011301603.html",
# "description": "이통3사는 연말정산 기간인 15일부터 3월 19일까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12 프로 맥스, 아이패드 에어4, 백화점 상품권 등의 경품을 증정한다.... ",
# "pubDate": "Wed, 13 Jan 2021 13:30:00 +0900"
#
# },
# {
# "title": "[최재붕의 ‘2020 포노 사피엔스 문명의 개막’(10 마지막 회)] 포노 사피엔스...",
# "originallink": "http://jmagazine.joins.com/monthly/view/332440",
# "link": "http://jmagazine.joins.com/monthly/view/332440",
# "description": "<b>아이폰</b>도 기술에서는 이제 삼성전자를 따라가는 형국이다. 삼성전자는 5G폰도 먼저 개발했고, 폴더블폰도 먼저 내놓았다. 그럼에도 불구하고 애플의 팬덤은 견고하다. <b>아이폰</b>12는 135만원의 고가 정책에도 불구하고... ",
# "pubDate": "Wed, 13 Jan 2021 13:23:00 +0900"
#
# },
# {
# "title": "쿠팡, 로켓모바일에 중고폰 보상판매 서비스 추가",
# "originallink": "http://news.kbiz.or.kr/news/articleView.html?idxno=76656",
# "link": "http://news.kbiz.or.kr/news/articleView.html?idxno=76656",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개로 다양하다. 신규 폰 구매 후 구매완료 페이지에서 '쓰던 폰 보상판매' 신청 버튼을 눌러 중고폰... ",
# "pubDate": "Wed, 13 Jan 2021 13:15:00 +0900"
#
# },
# {
# "title": "‘패스’ 두번 터치면 연말정산 접속 끝",
# "originallink": "http://news.heraldcorp.com/view.php?ud=20210113000652",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=016&aid=0001778568",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일 까지 패스 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12 프로... ",
# "pubDate": "Wed, 13 Jan 2021 13:14:00 +0900"
#
# },
# {
# "title": "이마트24, 보조배터리 공유서비스 '충전돼지' 도입",
# "originallink": "http://news.kbiz.or.kr/news/articleView.html?idxno=76655",
# "link": "http://news.kbiz.or.kr/news/articleView.html?idxno=76655",
# "description": "충전돼지 보조배터리에는 마이크로5핀, 라이트닝8핀(<b>아이폰</b>), C타입(갤럭시) 등 3개의 케이블이 있어 스마트폰을 비롯해 무선이어폰, 태블릿, 전자담배 등 다양한 전자기기의 충전을 동시에 할 수 있다. 최초 30분까지... ",
# "pubDate": "Wed, 13 Jan 2021 13:11:00 +0900"
#
# },
# {
# "title": "[노멀 피플]의 스타, 폴 메스칼의 세계를 돌파하는 일",
# "originallink": "http://www.gqkorea.co.kr/2021/01/13/%eb%85%b8%eb%a9%80-%ed%94%bc%ed%94%8c%ec%9d%98-%ec%8a%a4%ed%83%80-%ed%8f%b4-%eb%a9%94%ec%8a%a4%ec%b9%bc%ec%9d%98-%ec%84%b8%ea%b3%84%eb%a5%bc-%eb%8f%8c%ed%8c%8c%ed%95%98%eb%8a%94-%ec%9d%bc/?utm_source=naver&utm_medium=partnership",
# "link": "http://www.gqkorea.co.kr/2021/01/13/%eb%85%b8%eb%a9%80-%ed%94%bc%ed%94%8c%ec%9d%98-%ec%8a%a4%ed%83%80-%ed%8f%b4-%eb%a9%94%ec%8a%a4%ec%b9%bc%ec%9d%98-%ec%84%b8%ea%b3%84%eb%a5%bc-%eb%8f%8c%ed%8c%8c%ed%95%98%eb%8a%94-%ec%9d%bc/?utm_source=naver&utm_medium=partnership",
# "description": "폴 메스칼 앞의 테이블에는 2파운드짜리 라이터와 물 한 컵, 그리고 뒤집은 채 둔 그의 <b>아이폰</b>이 있다. 그의 손에는 패티 스미스의 책, 그 유명한 &lt;저스트 키즈&gt;가 아닌, “지적인 친구가 소개한” 다른 책이 들려 있다.... ",
# "pubDate": "Wed, 13 Jan 2021 13:05:00 +0900"
#
# },
# {
# "title": "[하이빔]애플 by 현대차와 현대차 by 애플",
# "originallink": "http://autotimes.hankyung.com/apps/news.sub_view?popup=0&nid=01&c1=01&c2=01&c3=00&nkey=202101131142181",
# "link": "http://autotimes.hankyung.com/apps/news.sub_view?popup=0&nid=01&c1=01&c2=01&c3=00&nkey=202101131142181",
# "description": "일각에서는 애플 <b>아이폰</b>을 대만 폭스콘이 위탁 생산한다는 점에서 현대차 또한 애플로부터 위탁 생산 제안을 받은 것으로 짐작하고 있다. 단순히 생산만 맡긴다면 애플이 중국이나 인도 업체와 손잡는 게 현명하지만... ",
# "pubDate": "Wed, 13 Jan 2021 13:03:00 +0900"
#
# },
# {
# "title": "[권상집의 인사이트] 뭉쳐야 산다?...현대차와 애플, 그리고 CJ와 NC",
# "originallink": "http://www.opinionnews.co.kr/news/articleView.html?idxno=45272",
# "link": "http://www.opinionnews.co.kr/news/articleView.html?idxno=45272",
# "description": "애플이 <b>아이폰</b> 제조사로 대만의 폭스콘을 선택했던 초기 대만은 환호를 질렀지만 폭스콘의 이익률은 4%도 되지 않는다. 현대차와 애플의 협력이 강력한 시너지를 낸다는 보장은 없다. 일러스트=연합뉴스 현대차가 &quot;아직... ",
# "pubDate": "Wed, 13 Jan 2021 13:03:00 +0900"
#
# },
# {
# "title": "'챗봇' 이루다 중단 후 펼쳐진 당혹스럽고 흥미로운 일",
# "originallink": "http://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0002710613&CMPT_CD=P0010&utm_source=naver&utm_medium=newsearch&utm_campaign=naver_news",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=047&aid=0002298679",
# "description": "▲  인공지능 챗봇 ‘이루다’ ⓒ 스캐터 랩 먼저 기존 <b>아이폰</b>의 시리나 각종 인공지능 스피커를 뛰어넘는 AI 기술이, 더 나아가 국내 기술이 여기까지 발전했나 싶어 놀라웠다. 반면, 일회적이고 즉물적인 대화의 가벼움은... ",
# "pubDate": "Wed, 13 Jan 2021 12:50:00 +0900"
#
# },
# {
# "title": "쿠팡, '최신폰 구매와 중고폰 보상 한번에' 서비스 개시",
# "originallink": "https://biz.sbs.co.kr/article_hub/20000000227?division=NAVER",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=374&aid=0000230654",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여 개입니다. 신규 폰 구매 후 구매완료 페이지에서 ‘쓰던 폰 보상판매’ 신청 버튼을 눌러 중고폰... ",
# "pubDate": "Wed, 13 Jan 2021 12:46:00 +0900"
#
# },
# {
# "title": "쿠팡, 로켓모바일에 중고폰 보상판매 서비스 추가",
# "originallink": "http://www.dt.co.kr/contents.html?article_no=2021011302109932727003&ref=naver",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002648729",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개로 다양하다. 신규 폰 구매 후 구매완료 페이지에서 '쓰던 폰 보상판매' 신청 버튼을 눌러 중고폰... ",
# "pubDate": "Wed, 13 Jan 2021 12:43:00 +0900"
#
# },
# {
# "title": "[Daily New쇼핑] 하이마트, 홈플러스, 11번가 外",
# "originallink": "http://biz.newdaily.co.kr/site/data/html/2021/01/13/2021011300117.html",
# "link": "http://biz.newdaily.co.kr/site/data/html/2021/01/13/2021011300117.html",
# "description": "충전돼지 보조배터리에는 마이크로5핀, 라이트닝8핀(<b>아이폰</b>), C타입(갤럭시) 등 3개의 케이블이 있어 스마트폰을 비롯해 무선이어폰, 태블릿, 전자담배 등 다양한 전자기기의 충전을 동시에 할 수 있다. 최초 30분까지... ",
# "pubDate": "Wed, 13 Jan 2021 12:41:00 +0900"
#
# },
# {
# "title": "영상을 보는 순간 흔들린다, 모플린",
# "originallink": "http://www.earlyadopter.co.kr/145854",
# "link": "http://www.earlyadopter.co.kr/145854",
# "description": "블루투스 4.2 방식으로 연결된 <b>아이폰</b>, 안드로이드폰에서 전송되는 주인 목소리를 듣고 반응하기도 한다. 조금 이상해 보이겠지만 털 옷을 벗겨 목욕(세탁)을 시킬 수도 있고 색상 변경도 가능하다. 400달러(약 44만원)... ",
# "pubDate": "Wed, 13 Jan 2021 12:39:00 +0900"
#
# },
# {
# "title": "쿠팡, 로켓모바일에 중고폰 보상판매 서비스 개시",
# "originallink": "http://biz.newdaily.co.kr/site/data/html/2021/01/13/2021011300094.html",
# "link": "http://biz.newdaily.co.kr/site/data/html/2021/01/13/2021011300094.html",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개로 다양하다. 신규 폰 구매 후 구매완료 페이지에서 ‘쓰던 폰 보상판매’ 신청 버튼을 눌러 중고폰... ",
# "pubDate": "Wed, 13 Jan 2021 12:30:00 +0900"
#
# },
# {
# "title": "쿠팡, 로켓모바일에 중고폰 보상판매 서비스 추가",
# "originallink": "http://www.cnbnews.com/news/article.html?no=475844",
# "link": "http://www.cnbnews.com/news/article.html?no=475844",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개에 달한다. 신규 폰 구매 후 구매완료 페이지에서 ‘쓰던 폰 보상판매’ 신청 버튼을 눌러 중고폰... ",
# "pubDate": "Wed, 13 Jan 2021 12:14:00 +0900"
#
# },
# {
# "title": "연말정산 서비스 접속, PASS로…&quot;공공서비스도 PASS 인증서로 쉽고 간편하게&quot;",
# "originallink": "http://www.econonews.co.kr/news/articleView.html?idxno=153540",
# "link": "http://www.econonews.co.kr/news/articleView.html?idxno=153540",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일 까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 12:10:00 +0900"
#
# },
# {
# "title": "통신 3사, '패스' 인증서 3초만에 무료 발급-15일부터 연말정산 서비스",
# "originallink": "http://www.techholic.co.kr/news/articleView.html?idxno=195895",
# "link": "http://www.techholic.co.kr/news/articleView.html?idxno=195895",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일 까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 12:05:00 +0900"
#
# },
# {
# "title": "“PASS로 연말정산 간편하게”···새 국민인증서 자리 노리는 이통3사",
# "originallink": "http://news.khan.co.kr/kh_news/khan_art_view.html?artid=202101131205001&code=920100",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=032&aid=0003053777",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 2월 19일 까지 패스 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 12:05:00 +0900"
#
# },
# {
# "title": "퍼플망고, 갤럭시S21 공개 D-2 'S20 BTS·울트라·Z 플립' 할인",
# "originallink": "http://www.beyondpost.co.kr/view.php?ud=2021011312013430486cf2d78c68_30",
# "link": "http://www.beyondpost.co.kr/view.php?ud=2021011312013430486cf2d78c68_30",
# "description": "이 외에도 LTE 스마트폰의 할인혜택을 강화해 갤럭시Z 플립 모델과 갤럭시노트9 모델을 각 30만원대, 20만원대로 할인하고 <b>아이폰</b>SE2 모델은 6만원대로 제공하며 <b>아이폰</b>7, 갤럭시A31 등을 추가 결제금 없는 현금가... ",
# "pubDate": "Wed, 13 Jan 2021 12:04:00 +0900"
#
# },
# {
# "title": "'갤럭시S21' 99만9900원…삼성전자, 3년 만에 가격 승부수",
# "originallink": "https://www.hankyung.com/it/article/202101137338g",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=015&aid=0004482875",
# "description": "반면 지난해 10월 글로벌 출시된 '<b>아이폰</b> 12'는 판매 흥행을 이어가고 있다. 실제로 시장조사업체... 애플의 첫 5G폰인 <b>아이폰</b>12가 출시된 지 두 달만에 삼성전자가 1년간 판매한 5G 스마트폰 대수를 뛰어넘은... ",
# "pubDate": "Wed, 13 Jan 2021 12:00:00 +0900"
#
# },
# {
# "title": "삼성전자 갤럭시S21 가격 확정…이번에는 얼마에 나올까?",
# "originallink": "http://news.mk.co.kr/newsRead.php?no=39909&year=2021",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=009&aid=0004732561",
# "description": "애플 <b>아이폰</b>12 시리즈 중 가장 가격이 낮은 제품이 95만원인 것도 갤럭시S21 가격 책정에 영향을 준 것으로 보인다. 시장조사기관 스트래티지 애널리틱스에 따르면 애플은 <b>아이폰</b> 출시 두 달 만에 지난해 5G... ",
# "pubDate": "Wed, 13 Jan 2021 11:51:00 +0900"
#
# },
# {
# "title": "[차트-모바일]겨울에 어울리는 게임 '스키 사파리' 순위 상승",
# "originallink": "http://www.fomos.kr/redirect/news_view?news_cate_id=10&entry_id=96361",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=236&aid=0000209564",
# "description": "■ <b>아이폰</b> 게임 순위 이번 주 <b>아이폰</b> 유료 게임 순위에서는 지난주 상위권 게임들의 순위가 소폭 하락한 가운데 하위권 게임들은 큰 폭으로 상승했다. 특히, 겨울에 어울리는 게임인 '스키 사파리'는 500원이라는... ",
# "pubDate": "Wed, 13 Jan 2021 11:48:00 +0900"
#
# },
# {
# "title": "확진자 동선과 겹치는지 알려주는 애플리케이션 출시",
# "originallink": "http://goodnews1.com/news/news_view.asp?seq=107197",
# "link": "http://goodnews1.com/news/news_view.asp?seq=107197",
# "description": "혼잡도 기반 길찾기 서비스, 통행 분석을 통한 나만의 이동 경로 제공, 교통약자를 위한 저상버스 예약 등 서비스를 제공한다. 이번에 출시되는 앱은 안드로이드 버전이며, <b>아이폰</b> 버전 개발은 다소 시간이 걸릴 전망이다.",
# "pubDate": "Wed, 13 Jan 2021 11:48:00 +0900"
#
# },
# {
# "title": "쿠팡, 로켓모바일에 ‘중고폰 보상판매’ 서비스 추가",
# "originallink": "http://www.megaeconomy.co.kr/news/newsview.php?ncode=1065580705840580",
# "link": "http://www.megaeconomy.co.kr/news/newsview.php?ncode=1065580705840580",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개로 다양하다. 신규 폰 구매 후 구매완료 페이지에서 ‘쓰던 폰 보상판매’ 신청 버튼을 눌러... ",
# "pubDate": "Wed, 13 Jan 2021 11:41:00 +0900"
#
# },
# {
# "title": "삼성 갤럭시S21, 가격·출시일정 다 나왔다… 99만9900원 확정",
# "originallink": "https://www.dnews.co.kr/uhtml/view.jsp?idxno=202101131130327590184",
# "link": "https://www.dnews.co.kr/uhtml/view.jsp?idxno=202101131130327590184",
# "description": "삼성전자는 애플의 <b>아이폰</b>12를 견제하고 전작의 부진을 만회하기 위해 다양한 가격대의 제품을 선보인 것으로 파악된다. 지난해 갤럭시S20 시리즈는 판매량이 전작의 70% 수준에 그친데 반해 <b>아이폰</b>12 시리즈는... ",
# "pubDate": "Wed, 13 Jan 2021 11:40:00 +0900"
#
# },
# {
# "title": "[남산사색] ‘호모 퀘스천스’ 만들기",
# "originallink": "http://news.heraldcorp.com/view.php?ud=20210113000511",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=103&oid=016&aid=0001778468",
# "description": "<b>아이폰</b>과 갤럭시폰의 차이는 “열심히”가 아닌 “미학적” 부분에서 나온다는 것. 이건 공부를 열심히 해서 되는 게 아니다. 이 문제는 “질문하지 않아서”라고 바꿔 답해도 비슷한 맥락이다. 최진석 서강대 명예교수는... ",
# "pubDate": "Wed, 13 Jan 2021 11:36:00 +0900"
#
# },
# {
# "title": "코로나 확진자와 동선 겹치면 자동으로 알려주는 교통 앱 나온다",
# "originallink": "http://www.kwnews.co.kr/nview.asp?aid=221011200181",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=087&aid=0000828563",
# "description": "<b>아이폰</b> 버전 개발은 다소 시간이 걸릴 것으로 시는 전망했다. 시는 교통 앱이 출시되면 확진자 접촉의심자가 신속하게 선제검사를 받을 수 있고, 정보 부족으로 인한 시민들의 불안감도 줄일 수 있을 것으로 기대했다.",
# "pubDate": "Wed, 13 Jan 2021 11:35:00 +0900"
#
# },
# {
# "title": "갤럭시S21 출고가 99만9900원…15일부터 사전예약",
# "originallink": "https://biz.sbs.co.kr/article_hub/20000000222?division=NAVER",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=374&aid=0000230632",
# "description": "갤럭시S20의 부진을 만회하고, 애플 <b>아이폰</b>12의 인기를 견제하기 위해 가격을 낮춘 것으로 풀이됩니다. 출고가를 낮추기 위해 갤럭시S21 시리즈 사양도 일부 하향 조정됐습니다. 삼성전자는 기본 구성품에서... ",
# "pubDate": "Wed, 13 Jan 2021 11:33:00 +0900"
#
# },
# {
# "title": "[IT&amp;e스포츠] 가벼움과 성능 모두를 잡다, 무선 게이밍 마우스 스틸시리즈 AE...",
# "originallink": "http://www.fomos.kr/redirect/news_view?news_cate_id=14&entry_id=96359",
# "link": "https://sports.news.naver.com/news.nhn?oid=236&aid=0000209559",
# "description": "스마트폰의 대명사인 애플은 <b>아이폰</b>에 충전용 케이블을 제외하고 모두 없앴고, 심지어는 맥세이프를 활용한 무선 충전 기술까지 내세우며 스마트폰을 선에서 해방시키려 한다. 이어폰과 헤드폰 시장 마찬가지.... ",
# "pubDate": "Wed, 13 Jan 2021 11:33:00 +0900"
#
# },
# {
# "title": "통신3사, 연말정산은 'PASS 인증서'로 쉽고 간편하게",
# "originallink": "http://www.100ssd.co.kr/news/articleView.html?idxno=74041",
# "link": "http://www.100ssd.co.kr/news/articleView.html?idxno=74041",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일 까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 11:28:00 +0900"
#
# },
# {
# "title": "삼성폰, CES 영상서 카메라 실종…‘갤노트21’ UDC 적용되나",
# "originallink": "https://www.dailian.co.kr/news/view/955132/?sc=Naver",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=119&aid=0002460067",
# "description": "애플은 ‘<b>아이폰</b>12’까지 전면 노치를 채용해 화면에서 상당 부분 손실이 발생한다는 지적을 받고 있다. 지금까지는 기술적으로 전면에 카메라를 넣기 위해 디스플레이 사용 면적을 줄일 수밖에 없었다. 이를 극복하기... ",
# "pubDate": "Wed, 13 Jan 2021 11:28:00 +0900"
#
# },
# {
# "title": "'애플카' 물밑 접촉 치열…벤츠 부터 카누까지",
# "originallink": "https://www.theguru.co.kr/news/article.html?no=17830",
# "link": "https://www.theguru.co.kr/news/article.html?no=17830",
# "description": "&lt;본보 2020년 9월 14일 참고 '현대차·만도 협업' 美 전기차 카누 &quot;2022년 첫 모델 출시&quot;&gt; 애플카 프로젝트가 가시화되고 있는 가운데 애플이 <b>아이폰</b>을 만들 때처럼 주문자생산(OEM) 방식을 전기차 사업 모델에도 적용할... ",
# "pubDate": "Wed, 13 Jan 2021 11:26:00 +0900"
#
# },
# {
# "title": "통신3사, 직장인 연말정산 'PASS 인증서'로… &quot;3초면 무료 발급 OK&quot;",
# "originallink": "http://news.kbiz.or.kr/news/articleView.html?idxno=76649",
# "link": "http://news.kbiz.or.kr/news/articleView.html?idxno=76649",
# "description": "통해 <b>아이폰</b> 12, 에어팟 프로, 스타벅스 모바일 상품권 등을 증정한다. 또 연말정산 기간인 15일부터 내달 19일 까지 PASS 인증서로 국세청 홈택스 연말정산간소화 서비스를 이용한 고객들에게 추첨을 통해 <b>아이폰</b> 12... ",
# "pubDate": "Wed, 13 Jan 2021 11:22:00 +0900"
#
# },
# {
# "title": "[유통오늘] CU, 신선 HMR 상품 '떠먹는 피자' 2종 순차 출시…홈앤쇼핑, ㈜에...",
# "originallink": "http://www.sisaon.co.kr/news/articleView.html?idxno=122828",
# "link": "http://www.sisaon.co.kr/news/articleView.html?idxno=122828",
# "description": "충전돼지 보조배터리에는 마이크로5핀, 라이트닝8핀(<b>아이폰</b>), C타입(갤럭시) 등 3개의 케이블이 있어 스마트폰을 비롯해 무선이어폰, 태블릿, 전자담배 등 다양한 전자기기의 충전을 동시에 할 수 있다. 최초 30분까지... ",
# "pubDate": "Wed, 13 Jan 2021 11:20:00 +0900"
#
# },
# {
# "title": "변동성 심한 코스피에 美 증시 몰린 서학개미",
# "originallink": "https://view.asiae.co.kr/article/2021011311174327096",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=277&aid=0004827756",
# "description": "특히 애플의 경우 <b>아이폰</b>12의 판매실적에 대한 기대가 커지고 있는데다 현대차그룹과 ‘애플카’를 공동 개발한다는 소식까지 더해지며 국내 투자자들의 관심이 높아졌다. 이후 현대차가 결정된 것이 없다고... ",
# "pubDate": "Wed, 13 Jan 2021 11:17:00 +0900"
#
# },
# {
# "title": "'나도 확진자 마주쳤나?'…동선 겹치면 알려주는 교통 앱",
# "originallink": "http://yna.kr/AKR20210112159300004?did=1195m",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=001&aid=0012137321",
# "description": "<b>아이폰</b> 버전 개발은 다소 시간이 걸릴 것으로 시는 전망했다. 황보연 서울시 도시교통실장은 &quot;스타트업·소기업 등이 누구나 자유롭게 데이터를 이용하고 사업화할 수 있는 교통 허브 생태계를 조성해 시민에게 더 많은... ",
# "pubDate": "Wed, 13 Jan 2021 11:15:00 +0900"
#
# },
# {
# "title": "[뉴스워커_외신] 인텔의 문제, 삼성 내부에도 있다…&quot;리더십 부재는 잠재적 매...",
# "originallink": "http://www.newsworker.co.kr/news/articleView.html?idxno=98904",
# "link": "http://www.newsworker.co.kr/news/articleView.html?idxno=98904",
# "description": "스마트폰 판매도 애플의 <b>아이폰</b>12와의 경쟁에서 부진했을 가능성이 있다. 다만, 삼성전자의 주요 수익원인 메모리칩 가격은 업계 전반의 공급 수요 감소와 서버 수요 개선에 힘입어 회복세를 보이고 있는 것으로... ",
# "pubDate": "Wed, 13 Jan 2021 11:13:00 +0900"
#
# },
# {
# "title": "쿠팡, 로켓모바일에 중고폰 보상판매 서비스 추가",
# "originallink": "http://www.thepublic.kr/news/newsview.php?ncode=1065576213265763",
# "link": "http://www.thepublic.kr/news/newsview.php?ncode=1065576213265763",
# "description": "중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 모델부터 <b>아이폰</b>6, 갤럭시8 등 구형 모델까지 약 100여개로 다양하다. 신규 폰 구매 후 구매완료 페이지에서 ‘쓰던 폰 보상판매’ 신청 버튼을 눌러 중고폰... ",
# "pubDate": "Wed, 13 Jan 2021 11:11:00 +0900"
#
# }
# ]
# }

# %% [markdown]
# ## pandas를 이용하여 읽기

# %%
import pandas as pd
import json

# %%
data = json.loads(response_body.decode('utf-8'))

# %%
df = pd.json_normalize(data['items'])

# %%
df
# Out:
#                                                 title  \
# 0   삼성, 갤럭시 S21 출고가 '확' 낮췄다…&quot;<b>아이폰</b> 12 견제...
# 1                [마켓트렌드] 전 국민 코로나19 백신 접종 '성큼'… 수혜주는?
# 2       12월 대만 IT매출 57조원 사상최대 기록...“재택수요 증대로 호황&quot;
# 3   '<b>아이폰</b> 잡아라'… 삼성 갤럭시S21, 충전기·이어폰 빼고 99만990...
# 4                   이번 연말정산은 민간 인증 서비스로…이통3사·카카오 등 각축
# ..                                                ...
# 95  [유통오늘] CU, 신선 HMR 상품 '떠먹는 피자' 2종 순차 출시…홈앤쇼핑, ㈜...
# 96                           변동성 심한 코스피에 美 증시 몰린 서학개미
# 97                    '나도 확진자 마주쳤나?'…동선 겹치면 알려주는 교통 앱
# 98  [뉴스워커_외신] 인텔의 문제, 삼성 내부에도 있다…&quot;리더십 부재는 잠재적...
# 99                         쿠팡, 로켓모바일에 중고폰 보상판매 서비스 추가
#
#                                          originallink  \
# 0   http://www.newsprime.co.kr/news/article.html?n...
# 1   https://news.mtn.co.kr/newscenter/news_viewer....
# 2   http://www.newsis.com/view/?id=NISX20210113_00...
# 3   http://www.getnews.co.kr/news/articleView.html...
# 4        http://yna.kr/AKR20210113134100017?did=1195m
# ..                                                ...
# 95  http://www.sisaon.co.kr/news/articleView.html?...
# 96  https://view.asiae.co.kr/article/2021011311174...
# 97       http://yna.kr/AKR20210112159300004?did=1195m
# 98  http://www.newsworker.co.kr/news/articleView.h...
# 99  http://www.thepublic.kr/news/newsview.php?ncod...
#
#                                                  link  \
# 0   http://www.newsprime.co.kr/news/article.html?n...
# 1   https://news.mtn.co.kr/newscenter/news_viewer....
# 2   https://news.naver.com/main/read.nhn?mode=LSD&...
# 3   http://www.getnews.co.kr/news/articleView.html...
# 4   https://news.naver.com/main/read.nhn?mode=LSD&...
# ..                                                ...
# 95  http://www.sisaon.co.kr/news/articleView.html?...
# 96  https://news.naver.com/main/read.nhn?mode=LSD&...
# 97  https://news.naver.com/main/read.nhn?mode=LSD&...
# 98  http://www.newsworker.co.kr/news/articleView.h...
# 99  http://www.thepublic.kr/news/newsview.php?ncod...
#
#                                           description  \
# 0   이는 애플의 첫 5G 단말 '<b>아이폰</b> 12' 시리즈의 높은 인기로 점유율...
# 1   - <b>아이폰</b>12 전모델 OLED 채택 '흥행 성공' - 삼성전자 A5 투...
# 2   <b>아이폰</b>과 서버에 강한 전자기기 위탁제조 훙하이 정밀도 32%나 크게 늘...
# 3   애플의 <b>아이폰</b>12 시리즈가 최저 95만원으로 책정된 점도 무시 못한 것...
# 4   14일까지 패스 인증서를 발급한 고객을 대상으로 추첨으로 <b>아이폰</b>12·에...
# ..                                                ...
# 95  충전돼지 보조배터리에는 마이크로5핀, 라이트닝8핀(<b>아이폰</b>), C타입(갤...
# 96  특히 애플의 경우 <b>아이폰</b>12의 판매실적에 대한 기대가 커지고 있는데다 ...
# 97  <b>아이폰</b> 버전 개발은 다소 시간이 걸릴 것으로 시는 전망했다. 황보연 서...
# 98  스마트폰 판매도 애플의 <b>아이폰</b>12와의 경쟁에서 부진했을 가능성이 있다....
# 99  중고보상 매입 가능 기종은 <b>아이폰</b>12, 갤럭시 S20 시리즈 등 최신 ...
#
#                             pubDate
# 0   Wed, 13 Jan 2021 16:08:00 +0900
# 1   Wed, 13 Jan 2021 16:05:00 +0900
# 2   Wed, 13 Jan 2021 16:03:00 +0900
# 3   Wed, 13 Jan 2021 16:01:00 +0900
# 4   Wed, 13 Jan 2021 16:01:00 +0900
# ..                              ...
# 95  Wed, 13 Jan 2021 11:20:00 +0900
# 96  Wed, 13 Jan 2021 11:17:00 +0900
# 97  Wed, 13 Jan 2021 11:15:00 +0900
# 98  Wed, 13 Jan 2021 11:13:00 +0900
# 99  Wed, 13 Jan 2021 11:11:00 +0900
#
# [100 rows x 5 columns]

# %% [markdown]
# ## paging을 이용하여 10,000 개의 뉴스 수집
# - query : 아이폰
# - display : 100
# - start : 1 ~ 100

# %%
def patch_news_by_page(query, display=10, start=1):
    import os
    import sys
    import urllib.request
    import json
    encText = urllib.parse.quote(query)
    url = "https://openapi.naver.com/v1/search/news.json?query=" + encText  + "&display=" + str(display) + "&start=" + str(start) # json 결과
    # url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
      response_body = response.read()
      # print(response_body.decode('utf-8'))
      # return response_body.decode('utf-8')
      return json.loads(response_body.decode('utf-8'))
    else:
      print("Error Code:" + rescode)
      return "Error Code:" + rescode

# %%
# data = patch_news_by_page("아이폰", 100, 1)

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html 
df = pd.DataFrame()

for page in range(1, 11): 
    data_page = patch_news_by_page("애플", 100, page)
    df_page = pd.json_normalize(data_page['items']) 
    df = df.append(df_page, ignore_index=True)

# %%
len(df)
# Out:
# 1000

# %%
df.head(5)
# Out:
#                                title  ...                          pubDate
# 0               01-08-2021 모닝뉴스 헤드라인  ...  Sat, 09 Jan 2021 00:45:00 +0900
# 1  ‘페이팔’ 올해부터 암호화폐 결제, 옐런은 과거 회의적 입장  ...  Sat, 09 Jan 2021 00:30:00 +0900
# 2       현대차·<b>애플</b> 자율주행 전기차 협업 추진  ...  Sat, 09 Jan 2021 00:22:00 +0900
# 3  [사설] 코로나 여파에도 삼성전자 우리 경제 버팀목 확인했다  ...  Sat, 09 Jan 2021 00:03:00 +0900
# 4       갤럭시S21, 출고가 낮출 예정, 사전예약 일정은?  ...  Sat, 09 Jan 2021 00:03:00 +0900
#
# [5 rows x 5 columns]

# %%
df[['title', 'description', 'pubDate']].head(5)
# Out:
#                                title  ...                          pubDate
# 0               01-08-2021 모닝뉴스 헤드라인  ...  Sat, 09 Jan 2021 00:45:00 +0900
# 1  ‘페이팔’ 올해부터 암호화폐 결제, 옐런은 과거 회의적 입장  ...  Sat, 09 Jan 2021 00:30:00 +0900
# 2       현대차·<b>애플</b> 자율주행 전기차 협업 추진  ...  Sat, 09 Jan 2021 00:22:00 +0900
# 3  [사설] 코로나 여파에도 삼성전자 우리 경제 버팀목 확인했다  ...  Sat, 09 Jan 2021 00:03:00 +0900
# 4       갤럭시S21, 출고가 낮출 예정, 사전예약 일정은?  ...  Sat, 09 Jan 2021 00:03:00 +0900
#
# [5 rows x 3 columns]

# %% [markdown]
# ### pandas dataframe to file
# ```
# df.to_csv
# df.to_excel
# df.to_json
# df.to_pickle
# df.to ...
# ```
# [api reference](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_pickle.html)

# %%
df.to_pickle('애플_news_20210109.pkl')

# %% [markdown]
# ## 컨텐츠 수집
# - 삼성(1,11)    : 10page * 100 = 1,000
# - 아이폰(1,101) : 100page * 100 = 10,000
# - 갤럭시(1,101)
# - 샤오미(1,101)

# %%
# df = pd.DataFrame()

# for page in range(1, 11): 
#     data_page = patch_news_by_page("삼성", 100, page)
#     df_page = pd.json_normalize(data_page['items']) 
#     df = df.append(df_page, ignore_index=True)
# df.to_pickle('삼성_news_20210109.pkl')

# %% [markdown]
# ### 함수 만들기

# %%
def get_contents(keyword, max_page):
    df = pd.DataFrame()

    for page in range(1, max_page+1): 
        data_page = patch_news_by_page(keyword, 100, page)
        df_page = pd.json_normalize(data_page['items']) 
        df = df.append(df_page, ignore_index=True)
    df.to_pickle(keyword + '_news_20210109.pkl')

# %%
get_contents("삼성", 10)

# %%
get_contents("아이폰", 100)

# %% [markdown]
# # 실습

# %% [markdown]
# - 애플_news_20210109.pkl (1,000 건)
# - 삼성_news_20210109.pkl (1,000 건)
# - 아이폰_news_20210109.pkl (10,000 건)
# - 갤럭시_news_20210109.pkl (10,000 건)
# - 샤오미_news_20210109.pkl (10,000 건)
#
# 데이터 생성하고 local pc에 다운로드
